# %% [markdown]
# <a href="https://colab.research.google.com/github/shintafiaa/HF_NLP_Course/blob/main/1_3_Transformer_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1 Classifier Pipeline

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 72.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 26.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 108.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.7 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline

# %%
classifier = pipeline("sentiment-analysis")
classifier("I've been waiting for HuggungFace course my whole life.")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# [{'label': 'POSITIVE', 'score': 0.996798574924469}]

# %%
classifier(["I am happy", "I am mad"])
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998801946640015},
#  {'label': 'NEGATIVE', 'score': 0.9996107220649719}]

# %% [markdown]
# #2 Zero Shot Classification Pipeline

# %%
classifier = pipeline("zero-shot-classification")
classifier (
    "This is a course about the Transformers library",
    candidate_labels=["education", "politics", "business"])
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# {'sequence': 'This is a course about the Transformers library',
#  'labels': ['education', 'business', 'politics'],
#  'scores': [0.8445998430252075, 0.11197364330291748, 0.04342653974890709]}

# %%
classifier(
    "I want to be book writer of self improvement. So, I can save more money.",
    candidate_labels=["education", "economy", "business"]
)
# Out:
# {'sequence': 'I want to be book writer of self improvement. So, I can save more money.',
#  'labels': ['education', 'economy', 'business'],
#  'scores': [0.4322531819343567, 0.32728907465934753, 0.24045772850513458]}

# %% [markdown]
# #3 Text Generator Pipeline

# %%
generator = pipeline("text-generation")
generator("In this course, we will teach you how to")
# Out:
# No model was supplied, defaulted to gpt2 and revision 6c0e608 (https://huggingface.co/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1353: UserWarning: Using `max_length`'s default (50) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# ...

# %%
generator("When there is a will,")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1353: UserWarning: Using `max_length`'s default (50) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# [{'generated_text': 'When there is a will, there is only one way to obtain it from the gods. A will (or a will with other people) cannot be found inside one of these worlds. Some are made of different and strange materials; some, but certainly'}]

# %%
generator("Life is like riding bicycle")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1353: UserWarning: Using `max_length`'s default (50) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# [{'generated_text': "Life is like riding bicycle to school. You're just getting it started."}]

# %% [markdown]
# `num_return_sequences` parameter controls the number of output sequences generated

# %%
generator("you never fail until you", max_length=50, num_return_sequences=3)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'you never fail until you turn up to that event," said Jim Murphy, a former state Democratic president who was chair of the party\'s civil justice committee in 2000.\n\nHis former wife, Donna, also ran for office, but she had to'},
#  {'generated_text': 'you never fail until you take up the mantle."\n\nThis has been a common theme throughout his career. In the late 1990s, he became a longtime Democrat and Republican as the party came to power. He now says he\'s a member of'},
#  {'generated_text': "you never fail until you get all these great opportunities. The only time you ever fail is when you have a full time job or one that pays well. And now we're in an incredibly good position—you've got your company in a very good"}]

# %%
generator("you never fail until you", max_length=50, num_return_sequences=5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "you never fail until you learn the wrong way. That's one of the greatest things to have.\n\nThe same philosophy can be applied to other life types as well. Those that do not follow the wrong path to success, often fail. In"},
#  {'generated_text': 'you never fail until you win," says Pertwee Smith, a senior lecturer in history and government at the Universite d\'Atelier Universitaire in Paris.\n\nWhile some will disagree, and some will try to change the political'},
#  {'generated_text': "you never fail until you get hit with a fireball.\n\nFor the rest of your life, unless everyone else gets hit, you'll probably remember how awful your first match was. A few players lost, in part because of what was probably not"},
# ...

# %%
generator = pipeline("text-generation", model="distilgpt2")
generator(
    "If you can't explain it simply, you",
    max_length = 30,
    num_return_sequences=2
)
# Out:
# ...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "If you can't explain it simply, you shouldn't be thinking I'm saying what is going on. I'm going to explain it a little more"},
#  {'generated_text': "If you can't explain it simply, you have to look at it as if it is a complex piece and then explain it, or you have to"}]

# %%
#pip install huggingface-cli
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement huggingface-cli (from versions: none)
# ERROR: No matching distribution found for huggingface-cli

# %%
# !pip install huggingface_hub
# from huggingface_hub import notebook_login
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# notebook_login()

# %%
generatorPuisi = pipeline("text-generation", model="Sultannn/gpt2-ft-id-puisi")
generatorPuisi("Malam ini ku sendiri")
# Out:
# ...
# All model checkpoint layers were used when initializing TFGPT2LMHeadModel.
#
# All the layers of TFGPT2LMHeadModel were initialized from the model checkpoint at Sultannn/gpt2-ft-id-puisi.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.
# ...
# Setting `pad_token_id` to `eos_token_id`:35000 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/tf_utils.py:854: UserWarning: Using `max_length`'s default (50) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# ...

# %% [markdown]
# #4 Mask Filling Pipeline

# %%
unmasker = pipeline("fill-mask")
unmasker("Today is <mask> day.", top_k=2)
# Out:
# No model was supplied, defaulted to distilroberta-base and revision ec58a5b (https://huggingface.co/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# [{'score': 0.14172880351543427,
#   'token': 127,
#   'token_str': ' my',
#   'sequence': 'Today is my day.'},
#  {'score': 0.10741578042507172,
#   'token': 21688,
#   'token_str': ' YOUR',
#   'sequence': 'Today is YOUR day.'}]

# %%
unmasker = pipeline("fill-mask", model="bert-base-cased")
unmasker("Today is [MASK] day.", top_k=2)
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [{'score': 0.4511657953262329,
#   'token': 1103,
#   'token_str': 'the',
#   'sequence': 'Today is the day.'},
#  {'score': 0.10902303457260132,
#   'token': 1412,
#   'token_str': 'our',
#   'sequence': 'Today is our day.'}]

# %% [markdown]
# #5 Named Entity Recognition

# %%
ner = pipeline("ner", grouped_entities=True)
ner("I love Andrew Tate. He lives in Dubai with his brother, Tristan. They both run The Real World company.")
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision f2482bf (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'entity_group': 'PER',
#   'score': 0.99923694,
#   'word': 'Andrew Tate',
#   'start': 7,
#   'end': 18},
#  {'entity_group': 'LOC',
#   'score': 0.9997173,
#   'word': 'Dubai',
#   'start': 32,
#   'end': 37},
#  {'entity_group': 'PER',
#   'score': 0.9986771,
#   'word': 'Tristan',
#   'start': 56,
#   'end': 63},
#  {'entity_group': 'ORG',
#   'score': 0.99303794,
#   'word': 'The Real World',
#   'start': 79,
#   'end': 93}]

# %%
ner = pipeline("ner", grouped_entities=False)
ner("I love Andrew Tate. He lives in Dubai with his brother, Tristan. They both run The Real World company.")
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision f2482bf (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/token_classification.py:169: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="none"` instead.
#   warnings.warn(
# [{'entity': 'I-PER',
#   'score': 0.9991634,
#   'index': 3,
#   'word': 'Andrew',
#   'start': 7,
#   'end': 13},
#  {'entity': 'I-PER',
#   'score': 0.9993105,
#   'index': 4,
#   'word': 'Tate',
#   'start': 14,
#   'end': 18},
#  {'entity': 'I-LOC',
#   'score': 0.9997173,
#   'index': 9,
#   'word': 'Dubai',
#   'start': 32,
#   'end': 37},
#  {'entity': 'I-PER',
#   'score': 0.9986771,
#   'index': 14,
#   'word': 'Tristan',
#   'start': 56,
# ...

# %%
ner("i love andrew tate. he lives in dubai with his brother, tristan. they both run the real world company.")
# Out:
# [{'entity_group': 'PER',
#   'score': 0.56210244,
#   'word': '##ristan',
#   'start': 57,
#   'end': 63}]

# %%
nerBert = pipeline("ner", model="dslim/bert-base-NER", grouped_entities=True)
nerBert("I love Andrew Tate. He lives in Dubai with his brother, Tristan. They both run The Real World company.")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/token_classification.py:169: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(
# [{'entity_group': 'PER',
#   'score': 0.99963534,
#   'word': 'Andrew Tate',
#   'start': 7,
#   'end': 18},
#  {'entity_group': 'LOC',
#   'score': 0.9997315,
#   'word': 'Dubai',
#   'start': 32,
#   'end': 37},
#  {'entity_group': 'PER',
#   'score': 0.99937904,
#   'word': 'Tristan',
#   'start': 56,
#   'end': 63},
#  {'entity_group': 'ORG',
#   'score': 0.98038673,
#   'word': 'The Real World',
#   'start': 79,
#   'end': 93}]

# %% [markdown]
# #6 Question Answering

# %%
question_answerer = pipeline("question-answering")
question_answerer(
    question="Where do I work?",
    context="My name is Sylvain and I work at Hugging Face in Brooklyn",
)
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# {'score': 0.6949767470359802, 'start': 33, 'end': 45, 'answer': 'Hugging Face'}

# %%
question_answerer = pipeline("question-answering")
question_answerer (
    question = "Who is Andrew Tate?",
    context = "Five time kick-boxer world champion is named Andrew Tate."
)
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# {'score': 0.5816329717636108,
#  'start': 10,
#  'end': 35,
#  'answer': 'kick-boxer world champion'}

# %%
question_answerer (
    question = "Who is Andrew Tate?",
    context = "Five time kick-boxer world champion is named Andrew Tate. He is the brother of Tristan. He is son of Emory Tate. He loves to play chess."
)
# Out:
# {'score': 0.12867608666419983,
#  'start': 10,
#  'end': 35,
#  'answer': 'kick-boxer world champion'}

# %%
question_answerer (
    question = "Who is Andrew Tate?",
    context = "Five time kick-boxer world champion is named Andrew Tate. Andrew Tate is the most google person in the world."
)
# Out:
# {'score': 0.15347160398960114,
#  'start': 73,
#  'end': 108,
#  'answer': 'the most google person in the world'}

# %% [markdown]
# #7 Summarization

# %%
summarizer = pipeline("summarization")
summarizer (
    """
    America has changed dramatically during recent years. Not only has the number of 
    graduates in traditional engineering disciplines such as mechanical, civil, 
    electrical, chemical, and aeronautical engineering declined, but in most of 
    the premier American universities engineering curricula now concentrate on 
    and encourage largely the study of engineering science. As a result, there 
    are declining offerings in engineering subjects dealing with infrastructure, 
    the environment, and related issues, and greater concentration on high 
    technology subjects, largely supporting increasingly complex scientific 
    developments. While the latter is important, it should not be at the expense 
    of more traditional engineering.

    Rapidly developing economies such as China and India, as well as other 
    industrial countries in Europe and Asia, continue to encourage and advance 
    the teaching of engineering. Both China and India, respectively, graduate 
    six and eight times as many traditional engineers as does the United States. 
    Other industrial countries at minimum maintain their output, while America 
    suffers an increasingly serious decline in the number of engineering graduates 
    and a lack of well-educated engineers.
"""
)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# [{'summary_text': ' America has changed dramatically during recent years . The number of engineering graduates in the U.S. has declined in traditional engineering disciplines such as mechanical, civil,    electrical, chemical, and aeronautical engineering . Rapidly developing economies such as China and India continue to encourage and advance the teaching of engineering .'}]

# %%
summarizer (
    """
    America has changed dramatically during recent years. Not only has the number of 
    graduates in traditional engineering disciplines such as mechanical, civil, 
    electrical, chemical, and aeronautical engineering declined, but in most of 
    the premier American universities engineering curricula now concentrate on 
    and encourage largely the study of engineering science. As a result, there 
    are declining offerings in engineering subjects dealing with infrastructure, 
    the environment, and related issues, and greater concentration on high 
    technology subjects, largely supporting increasingly complex scientific 
    developments. While the latter is important, it should not be at the expense 
    of more traditional engineering.

    Rapidly developing economies such as China and India, as well as other 
    industrial countries in Europe and Asia, continue to encourage and advance 
    the teaching of engineering. Both China and India, respectively, graduate 
    six and eight times as many traditional engineers as does the United States. 
    Other industrial countries at minimum maintain their output, while America 
    suffers an increasingly serious decline in the number of engineering graduates 
    and a lack of well-educated engineers.
"""
)
# Out:
# [{'summary_text': ' America has changed dramatically during recent years . The number of engineering graduates in the U.S. has declined in traditional engineering disciplines such as mechanical, civil,    electrical, chemical, and aeronautical engineering . Rapidly developing economies such as China and India continue to encourage and advance the teaching of engineering .'}]

# %% [markdown]
# #7 Translation Pipeline

# %%
# !pip install datasets evaluate transformers[sentencepiece]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 71.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 16.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 27.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 17.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 79.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 30.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 85.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.7 MB/s eta 0:00:00
# ...

# %%
pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 23.5 MB/s eta 0:00:00
# ...

# %%
translator = pipeline("translation", model="Helsinki-NLP/opus-mt-fr-en")
translator("Ce cours est produit par Hugging Face.")
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# [{'translation_text': 'This course is produced by Hugging Face.'}]

# %%
translator = pipeline("translation_en_to_fr")
translator("This course is produced by Hugging Face.")
# Out:
# No model was supplied, defaulted to t5-base and revision 686f1db (https://huggingface.co/t5-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/tokenization_t5_fast.py:155: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
# ...
